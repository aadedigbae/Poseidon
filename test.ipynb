# %%
import joblib
from pathlib import Path

ROOT = Path.cwd()
# Adjust this path to your correct project root if needed
model_path = ROOT / "artifacts" / "model_registry" / "model1_risk_classifier.joblib"

bundle = joblib.load(model_path)

print("==== MODEL 1 BUNDLE KEYS ====")
for k in bundle.keys():
    print(" -", k)

print("\n==== TYPES ====")
for k, v in bundle.items():
    print(f"{k}: {type(v)}")

# Pretty print contents
import pprint
print("\n==== BUNDLE CONTENT PREVIEW ====")
pprint.pprint(bundle)
# Out:
# ==== MODEL 1 BUNDLE KEYS ====
#  - model
#  - features
#  - classes
#  - thresholds
#  - version
#  - config_used
#  - notes
#
# ==== TYPES ====
# model: <class 'sklearn.calibration.CalibratedClassifierCV'>
# features: <class 'list'>
# classes: <class 'list'>
# thresholds: <class 'dict'>
# version: <class 'str'>
# config_used: <class 'str'>
# notes: <class 'str'>
#
# ==== BUNDLE CONTENT PREVIEW ====
# {'classes': ['HIGH', 'LOW', 'MEDIUM'],
#  'config_used': 'thresholds.yml',
#  'features': ['temperature',
#               'pH',
#               'turbidity_proxy',
#               'predicted_do',
#               'predicted_nh3'],
#  'model': CalibratedClassifierCV(cv='prefit',
#                        estimator=GradientBoostingClassifier(random_state=42),
#                        method='isotonic'),
#  'notes': 'Calibrated (isotonic); thresholds tuned to emphasize HIGH recall.',
#  'thresholds': {'HIGH': 0.3},
#  'version': 'model1_risk_classifier_v1'}
