# %%
import pandas as pd
df = pd.read_excel("Monteria_Aquaculture_Data.xlsx")  # or your actual raw Montería path
print("Raw Montería rows:", len(df))

# Now load the trusted set from your current 03.1
df_trusted = pd.read_csv("interim/monteria_pseudolabeled_trusted.csv")
print("Trusted rows:", len(df_trusted))

print(df_trusted['risk_blended'].value_counts())
# Out:
# Raw Montería rows: 4345
# Trusted rows: 8
# risk_blended
# MEDIUM    6
# LOW       2
# Name: count, dtype: int64
